# %%
from pyspark.sql.functions import *

# %%
file_path="/Volumes/pyspark/spark_practice/csv_files/employees_data.csv";
print(file_path)

# %%
df = spark.read.format("csv").load(file_path)
df = spark.read.format("csv").option("header","true").load(file_path)
df = spark.read.format("csv").option("header", "true").option("inferSchema", "true").load(file_path)

# %%
df.display()

# %%
df.show(25)

# %%
df.printSchema()

# %%
df.describe().display()

# %%
df.select("first_name","last_name","city")
df.display()

# %%
df2 = df.select("first_name", "last_name","city")
df2.display()

# %%
df2 = df.select(col("first_name"),col("last_name"),col("city"))
df2.show()

# %%
df2 = df.filter(col("city") == "Bangalore").display()

# %%
df2 = df.filter(col("city") == "Bangalore").select("first_name","last_name","city").display()

# %%
df2 = df.filter(col("city") == "Bangalore").select("first_name","last_name","city").orderBy(col("first_name").desc()).display()

# %%
df2 = df.filter((col("city") == "Bangalore") & (col("department")=="Engineering")).select("first_name","last_name","city","department").orderBy(col("first_name").desc()).limit(3).display()
